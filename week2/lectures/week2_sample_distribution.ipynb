# %% [markdown]
# # Sample Distribution

# %%
import pandas as pd
import numpy as np

import sklearn.datasets
import sklearn.model_selection

import sklearn.metrics as skm

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset

# %%
dataset = sklearn.datasets.load_iris(as_frame=True)

target_num2name = {ix: str(name) for ix, name in enumerate(dataset['target_names'])}
feature_names = dataset['feature_names']
dataset_df = dataset['frame']
dataset_df['named_target'] = dataset_df['target'].map(target_num2name)
dataset_df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
#
#    target named_target
# 0       0       setosa
# 1       0       setosa
# 2       0       setosa

# %% [markdown]
# ### Single Samples

# %%
fig, ax = plt.subplots(1,1,figsize=(7,2))

# visualize single datapoints
sns.stripplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    ax = ax,
    alpha=0.1,
    color = 'k'
)
# Out:
# <Axes: xlabel='named_target', ylabel='sepal length (cm)'>

# %% [markdown]
# ### Sample Statistics

# %% [markdown]
# #### Mean and Standard Deviation

# %%
fig, ax = plt.subplots(1,1,figsize=(7,2))

# visualize single datapoints
sns.stripplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    ax = ax,
    alpha=0.1,
    color = 'k'
)

# visualize mean + sd 
sns.pointplot(
    dataset_df, 
    x='named_target', 
    y='sepal length (cm)', 
    errorbar="sd", 
    capsize=.02,
    color='orange',
    linestyle = ''
)
# Out:
# <Axes: xlabel='named_target', ylabel='sepal length (cm)'>

# %% [markdown]
# #### Median & Quartiles

# %%
fig, ax = plt.subplots(1,1,figsize=(7,2))

_ = sns.stripplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    ax = ax,
    alpha=0.1,
    color='k'
)

_ = sns.boxplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    whis = (0,100),
    fill = False,
    ax = ax,
    color = 'r',
    width = 0.3
)

# %% [markdown]
# #### Percentiles

# %%
fig, ax = plt.subplots(1,1,figsize=(7,2))

_ = sns.stripplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    ax = ax,
    alpha=0.1,
    color='k'
)

_ = sns.boxenplot(
    dataset_df,
    y = 'sepal length (cm)',
    x = 'named_target',
    fill = False,
    ax = ax,
    color = 'r',
    width = 0.3,
    k_depth='full',
)
